# %%
import pandas as pd

# %%
PATH = "movies.csv"

df = pd.read_csv(PATH)
df.sort_values(by='revenue', axis=0, ascending=False, inplace=False)
# Out:
#     Unnamed: 0      id                               film     revenue  \
# 0            0  299534                  Avengers: Endgame  2797800564
# 80           0  140607       Star Wars: The Force Awakens  2068223624
# 20           0  299536             Avengers: Infinity War  2046239637
# 81           1  135397                     Jurassic World  1671713208
# 1            1  420818                      The Lion King  1656943394
# ..         ...     ...                                ...         ...
# 17          17  466272     Once Upon a Time… in Hollywood   374251247
# 98          18  228161                               Home   368871007
# 18          18  287947                            Shazam!   363533271
# 99          19  105864                  The Good Dinosaur   331926147
# 19          19  458156  John Wick: Chapter 3 - Parabellum   326699296
#
#                       genres  vote_count  vote_average release_date  \
# ...

# %%
genres = pd.read_csv('genre_codes.csv')
# genres

# %%
df = pd.read_csv('budget_page1.csv')

# %%
# Out:
#     Unnamed: 0          Date                                         Name  \
# 0            0  Apr 23, 2019                            Avengers: Endgame
# 1            1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2            2  Apr 22, 2015                      Avengers: Age of Ultron
# 3            3  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4            4  Apr 25, 2018                       Avengers: Infinity War
# ..         ...           ...                                          ...
# 95          95  Aug 10, 2007                                  Rush Hour 3
# 96          96  Jun 27, 2016                         The Legend of Tarzan
# 97          97  Nov 23, 2011                                         Hugo
# 98          98  Jul 20, 2017  Valerian and the City of a Thousand Planets
# 99          99   Feb 6, 2015                            Jupiter Ascending
#
#            Budget
# 0    $400,000,000
# 1    $379,000,000
# 2    $365,000,000
# ...
