# %%
import pandas as pd

# %%
#pd.read_csv('2019_world_wide_box_office.csv')
#pd.read_csv('2019_world_wide_box_office.csv')
# Out:
#      Unnamed: 0  Rank                 Release Group       Worldwide  \
# 0             0     1             Avengers: Endgame  $2,797,800,564
# 1             1     2                 The Lion King  $1,656,943,394
# 2             2     3                     Frozen II  $1,448,800,077
# 3             3     4     Spider-Man: Far from Home  $1,131,927,996
# 4             4     5                Captain Marvel  $1,128,274,794
# ..          ...   ...                           ...             ...
# 674         674   675  Jimi Hendrix Electric Church          $1,818
# 675         675   676                      Game Day          $1,624
# 676         676   677           The Hours and Times          $1,273
# 677         677   678              The Untold Story            $790
# 678         678   679                    The Portal            $685
#
#          Domestic      %         Foreign    %.1
# 0    $858,373,000  30.7%  $1,939,427,564  69.3%
# 1    $543,638,043  32.8%  $1,113,305,351  67.2%
# ...

# %%
df=pd.read_csv('2015_2019WorldWideBoxOffice.csv')
df.head(10)
# Out:
#    Unnamed: 0  Rank                               Release Group  \
# 0           0     1  Star Wars: Episode VII - The Force Awakens
# 1           1     2                              Jurassic World
# 2           2     3                                   Furious 7
# 3           3     4                     Avengers: Age of Ultron
# 4           4     5                                     Minions
# 5           5     6                                     Spectre
# 6           6     7                                  Inside Out
# 7           7     8          Mission: Impossible - Rogue Nation
# 8           8     9       The Hunger Games: Mockingjay - Part 2
# 9           9    10                                 The Martian
#
#         Worldwide      Domestic      %         Foreign    %.1
# 0  $2,068,223,624  $936,662,225  45.3%  $1,131,561,399  54.7%
# 1  $1,670,400,637  $652,270,625    39%  $1,018,130,012    61%
# 2  $1,515,047,671  $353,007,020  23.3%  $1,162,040,651  76.7%
# ...
